# %%
import requests
import xmltodict

url = 'http://www.cbr.ru/scripts/XML_daily.asp'
response = requests.get(url)
response
# Out:
# <Response [200]>

# %%
response.content
# Out:
# b'<?xml version="1.0" encoding="windows-1251"?><ValCurs Date="28.09.2022" name="Foreign Currency Market"><Valute ID="R01010"><NumCode>036</NumCode><CharCode>AUD</CharCode><Nominal>1</Nominal><Name>\xc0\xe2\xf1\xf2\xf0\xe0\xeb\xe8\xe9\xf1\xea\xe8\xe9 \xe4\xee\xeb\xeb\xe0\xf0</Name><Value>37,8200</Value></Valute><Valute ID="R01020A"><NumCode>944</NumCode><CharCode>AZN</CharCode><Nominal>1</Nominal><Name>\xc0\xe7\xe5\xf0\xe1\xe0\xe9\xe4\xe6\xe0\xed\xf1\xea\xe8\xe9 \xec\xe0\xed\xe0\xf2</Name><Value>34,2209</Value></Valute><Valute ID="R01035"><NumCode>826</NumCode><CharCode>GBP</CharCode><Nominal>1</Nominal><Name>\xd4\xf3\xed\xf2 \xf1\xf2\xe5\xf0\xeb\xe8\xed\xe3\xee\xe2 \xd1\xee\xe5\xe4\xe8\xed\xe5\xed\xed\xee\xe3\xee \xea\xee\xf0\xee\xeb\xe5\xe2\xf1\xf2\xe2\xe0</Name><Value>62,7540</Value></Valute><Valute ID="R01060"><NumCode>051</NumCode><CharCode>AMD</CharCode><Nominal>100</Nominal><Name>\xc0\xf0\xec\xff\xed\xf1\xea\xe8\xf5 \xe4\xf0\xe0\xec\xee\xe2</Name><Value>14,1954</Value></Valute><Valute ID="R01090B"><NumCode>933</NumCode><CharCode>BYN</CharCode><Nominal>1</Nominal><Name>\xc1\xe5\xeb\xee\xf0\xf3\xf1\xf1\xea\xe8\xe9 \xf0\xf3\xe1\xeb\xfc</Name><Value>23,3674</Value></Valute><Valute ID="R01100"><NumCode>975</NumCode><CharCode>BGN</CharCode><Nominal>1</Nominal><Name>\xc1\xee\xeb\xe3\xe0\xf0\xf1\xea\xe8\xe9 \xeb\xe5\xe2</Name><Value>28,6919</Value></Valute><Valute ID="R01115"><NumCode>986</NumCode><CharCode>BRL</CharCode><Nominal>1</Nominal><Name>\xc1\xf0\xe0\xe7\xe8\xeb\xfc\xf1\xea\xe8\xe9 \xf0\xe5\xe0\xeb</Name><Value>10,8648</Value></Valute><Valute ID="R01135"><NumCode>348</NumCode><CharCode>HUF</CharCode><Nominal>100</Nominal><Name>\xc2\xe5\xed\xe3\xe5\xf0\xf1\xea\xe8\xf5 \xf4\xee\xf0\xe8\xed\xf2\xee\xe2</Name><Value>13,7411</Value></Valute><Valute ID="R01200"><NumCode>344</NumCode><CharCode>HKD</CharCode><Nominal>10</Nominal><Name>\xc3\xee\xed\xea\xee\xed\xe3\xf1\xea\xe8\xf5 \xe4\xee\xeb\xeb\xe0\xf0\xee\xe2</Name><Value>74,2414</Value></Valute><Valute ID="R01215"><NumCode>208</NumCode><CharCode>DKK</CharCode><Nominal>10</Nominal><Name>\xc4\xe0\xf2\xf1\xea\xe8\xf5 \xea\xf0\xee\xed</Name><Value>75,4606</Value></Valute><Valute ID="R01235"><NumCode>840</NumCode><CharCode>USD</CharCode><Nominal>1</Nominal><Name>\xc4\xee\xeb\xeb\xe0\xf0 \xd1\xd8\xc0</Name><Value>58,1756</Value></Valute><Valute ID="R01239"><NumCode>978</NumCode><CharCode>EUR</CharCode><Nominal>1</Nominal><Name>\xc5\xe2\xf0\xee</Name><Value>55,9953</Value></Valute><Valute ID="R01270"><NumCode>356</NumCode><CharCode>INR</CharCode><Nominal>100</Nominal><Name>\xc8\xed\xe4\xe8\xe9\xf1\xea\xe8\xf5 \xf0\xf3\xef\xe8\xe9</Name><Value>73,0136</Value></Valute><Valute ID="R01335"><NumCode>398</NumCode><CharCode>KZT</CharCode><Nominal>100</Nominal><Name>\xca\xe0\xe7\xe0\xf5\xf1\xf2\xe0\xed\xf1\xea\xe8\xf5 \xf2\xe5\xed\xe3\xe5</Name><Value>12,1867</Value></Valute><Valute ID="R01350"><NumCode>124</NumCode><CharCode>CAD</CharCode><Nominal>1</Nominal><Name>\xca\xe0\xed\xe0\xe4\xf1\xea\xe8\xe9 \xe4\xee\xeb\xeb\xe0\xf0</Name><Value>42,4144</Value></Valute><Valute ID="R01370"><NumCode>417</NumCode><CharCode>KGS</CharCode><Nominal>100</Nominal><Name>\xca\xe8\xf0\xe3\xe8\xe7\xf1\xea\xe8\xf5 \xf1\xee\xec\xee\xe2</Name><Value>72,2618</Value></Valute><Valute ID="R01375"><NumCode>156</NumCode><CharCode>CNY</CharCode><Nominal>10</Nominal><Name>\xca\xe8\xf2\xe0\xe9\xf1\xea\xe8\xf5 \xfe\xe0\xed\xe5\xe9</Name><Value>81,0556</Value></Valute><Valute ID="R01500"><NumCode>498</NumCode><CharCode>MDL</CharCode><Nominal>10</Nominal><Name>\xcc\xee\xeb\xe4\xe0\xe2\xf1\xea\xe8\xf5 \xeb\xe5\xe5\xe2</Name><Value>29,8563</Value></Valute><Valute ID="R01535"><NumCode>578</NumCode><CharCode>NOK</CharCode><Nominal>10</Nominal><Name>\xcd\xee\xf0\xe2\xe5\xe6\xf1\xea\xe8\xf5 \xea\xf0\xee\xed</Name><Value>54,1965</Value></Valute><Valute ID="R01565"><NumCode>985</NumCode><CharCode>PLN</CharCode><Nominal>1</Nominal><Name>\xcf\xee\xeb\xfc\xf1\xea\xe8\xe9 \xe7\xeb\xee\xf2\xfb\xe9</Name><Value>11,7781</Value></Valute>< ...

# %%
data = xmltodict.parse(response.content)
data
# Out:
# {'ValCurs': {'@Date': '28.09.2022',
#   '@name': 'Foreign Currency Market',
#   'Valute': [{'@ID': 'R01010',
#     'NumCode': '036',
#     'CharCode': 'AUD',
#     'Nominal': '1',
#     'Name': 'Австралийский доллар',
#     'Value': '37,8200'},
#    {'@ID': 'R01020A',
#     'NumCode': '944',
#     'CharCode': 'AZN',
#     'Nominal': '1',
#     'Name': 'Азербайджанский манат',
#     'Value': '34,2209'},
#    {'@ID': 'R01035',
#     'NumCode': '826',
#     'CharCode': 'GBP',
#     'Nominal': '1',
#     'Name': 'Фунт стерлингов Соединенного королевства',
#     'Value': '62,7540'},
#    {'@ID': 'R01060',
#     'NumCode': '051',
#     'CharCode': 'AMD',
#     'Nominal': '100',
#     'Name': 'Армянских драмов',
#     'Value': '14,1954'},
#    {'@ID': 'R01090B',
#     'NumCode': '933',
#     'CharCode': 'BYN',
#     'Nominal': '1',
#     'Name': 'Белорусский рубль',
#     'Value': '23,3674'},
#    {'@ID': 'R01100',
#     'NumCode': '975',
#     'CharCode': 'BGN',
#     'Nominal': '1',
#     'Name': 'Болгарский лев',
#     'Value': '28,6919'},
#    {'@ID': 'R01115',
#     'NumCode': '986',
#     'CharCode': 'BRL',
#     'Nominal': '1',
#     'Name': 'Бразильский реал',
#     'Value': '10,8648'},
#    {'@ID': 'R01135',
#     'NumCode': '348',
#     'CharCode': 'HUF',
#     'Nominal': '100',
#     'Name': 'Венгерских форинтов',
#     'Value': '13,7411'},
#    {'@ID': 'R01200',
#     'NumCode': '344',
#     'CharCode': 'HKD',
#     'Nominal': '10',
#     'Name': 'Гонконгских долларов',
#     'Value': '74,2414'},
#    {'@ID': 'R01215',
#     'NumCode': '208',
#     'CharCode': 'DKK',
#     'Nominal': '10',
#     'Name': 'Датских крон',
#     'Value': '75,4606'},
#    {'@ID': 'R01235',
#     'NumCode': '840',
#     'CharCode': 'USD',
#     'Nominal': '1',
#     'Name': 'Доллар США',
#     'Value': '58,1756'},
#    {'@ID': 'R01239',
#     'NumCode': '978',
#     'CharCode': 'EUR',
#     'Nominal': '1',
#     'Name': 'Евро',
#     'Value': '55,9953'},
#    {'@ID': 'R01270',
#     'NumCode': '356',
#     'CharCode': 'INR',
#     'Nominal': '100',
#     'Name': 'Индийских рупий',
#     'Value': '73,0136'},
#    {'@ID': 'R01335',
#     'NumCode': '398',
#     'CharCode': 'KZT',
#     'Nominal': '100',
#     'Name': 'Казахстанских тенге',
#     'Value': '12,1867'},
#    {'@ID': 'R01350',
#     'NumCode': '124',
#     'CharCode': 'CAD',
#     'Nominal': '1',
#     'Name': 'Канадский доллар',
#     'Value': '42,4144'},
#    {'@ID': 'R01370',
#     'NumCode': '417',
#     'CharCode': 'KGS',
#     'Nominal': '100',
#     'Name': 'Киргизских сомов',
#     'Value': '72,2618'},
#    {'@ID': 'R01375',
#     'NumCode': '156',
#     'CharCode': 'CNY',
#     'Nominal': '10',
#     'Name': 'Китайских юаней',
#     'Value': '81,0556'},
#    {'@ID': 'R01500',
#     'NumCode': '498',
#     'CharCode': 'MDL',
#     'Nominal': '10',
#     'Name': 'Молдавских леев',
#     'Value': '29,8563'},
#    {'@ID': 'R01535',
#     'NumCode': '578',
#     'CharCode': 'NOK',
#     'Nominal': '10',
#     'Name': 'Норвежских крон',
#     'Value': '54,1965'},
#    {'@ID': 'R01565',
#     'NumCode': '985',
#     'CharCode': 'PLN',
#     'Nominal': '1',
#     'Name': 'Польский злотый',
#     'Value': '11,7781'},
#    {'@ID': 'R01585F',
#     'NumCode': '946',
#     'CharCode': 'RON',
#     'Nominal': '1',
#     'Name': 'Румынский лей',
#     'Value': '11,3228'},
#    {'@ID': 'R01589',
#     'NumCode': '960',
#     'CharCode': 'XDR',
#     'Nominal': '1',
#     'Name': 'СДР (специальные права заимствования)',
#     'Value': '73,9988'},
#    {'@ID': 'R01625',
#     'NumCode': '702',
#     'CharCode': 'SGD',
#     'Nominal': '1',
#     'Name': 'Сингапурский доллар',
#     'Value': '40,5292'},
#    {'@ID': 'R01670',
#     'NumCode': '972',
#     'CharCode': 'TJS',
#     'Nominal': '10',
#     'Name': 'Таджикских сомони',
#     'Value': '56,8993'},
#    {'@ID': 'R01700J',
#     'NumCode': '949',
#     'CharCode': 'TRY',
#     'Nominal': '10',
#     'Name': 'Турецких лир',
#     'Value': '31,5431'},
#    {'@ID': 'R01710A',
#     'NumCode': '934',
#     'CharCode': 'TMT',
#     'Nominal': '1',
#     'Name': 'Новый туркменский манат',
#     'Value': '16,6216'},
#    {'@ID': 'R01717',
#     'NumCode': '860',
#     'CharCode': 'UZS',
#     'Nominal': '10000',
#     'Name': 'Узбекских сумов',
#     'Value': '52,6558'},
#    {'@ID': 'R01720',
#     'NumCode': '980',
#     'CharCode': 'UAH',
#     'Nominal': '10',
#     'Name': 'Украинских гривен',
#     'Value': '15,7579'},
#    {'@ID': 'R01760',
#     'NumCode': '203',
#     'CharCode': 'CZK',
#     'Nominal': '10',
#     'Name': 'Чешских крон',
#     'Value': '22,7836'},
#    {'@ID': 'R01770',
#     'NumCode': '752',
#     'CharCode': 'SEK',
#     'Nominal': '10',
#     'Name': 'Шведских крон',
#     'Value': '51,7604'},
#    {'@ID': 'R01775',
#     'NumCode': '756',
#     'CharCode': 'CHF',
#     'Nominal': '1',
#     'Name': 'Швейцарский франк',
#     'Value': '58,8703'},
#    {'@ID': 'R01810',
#     'NumCode': '710',
#     'CharCode': 'ZAR',
#     'Nominal': '10',
#     'Name': 'Южноафриканских рэндов',
#     'Value': '32,4019'},
#    {'@ID': 'R01815',
#     'NumCode': '410',
#     'CharCode': 'KRW',
#     'Nominal': '1000',
#     'Name': 'Вон Республики Корея',
#     'Value': '40,9255'},
#    {'@ID': 'R01820',
#     'NumCode': '392',
#     'CharCode': 'JPY',
#     'Nominal': '100',
#     'Name': 'Японских иен',
#     'Value': '40,2739'}]}}

# %%
items = []
for item in data['ValCurs']['Valute']:
    items.append(item)
items
# Out:
# [{'@ID': 'R01010',
#   'NumCode': '036',
#   'CharCode': 'AUD',
#   'Nominal': '1',
#   'Name': 'Австралийский доллар',
#   'Value': '37,8200'},
#  {'@ID': 'R01020A',
#   'NumCode': '944',
#   'CharCode': 'AZN',
#   'Nominal': '1',
#   'Name': 'Азербайджанский манат',
#   'Value': '34,2209'},
#  {'@ID': 'R01035',
#   'NumCode': '826',
#   'CharCode': 'GBP',
#   'Nominal': '1',
#   'Name': 'Фунт стерлингов Соединенного королевства',
#   'Value': '62,7540'},
#  {'@ID': 'R01060',
#   'NumCode': '051',
#   'CharCode': 'AMD',
#   'Nominal': '100',
#   'Name': 'Армянских драмов',
#   'Value': '14,1954'},
#  {'@ID': 'R01090B',
#   'NumCode': '933',
#   'CharCode': 'BYN',
#   'Nominal': '1',
#   'Name': 'Белорусский рубль',
#   'Value': '23,3674'},
#  {'@ID': 'R01100',
#   'NumCode': '975',
#   'CharCode': 'BGN',
#   'Nominal': '1',
#   'Name': 'Болгарский лев',
#   'Value': '28,6919'},
#  {'@ID': 'R01115',
#   'NumCode': '986',
#   'CharCode': 'BRL',
#   'Nominal': '1',
#   'Name': 'Бразильский реал',
#   'Value': '10,8648'},
#  {'@ID': 'R01135',
#   'NumCode': '348',
#   'CharCode': 'HUF',
#   'Nominal': '100',
#   'Name': 'Венгерских форинтов',
#   'Value': '13,7411'},
#  {'@ID': 'R01200',
#   'NumCode': '344',
#   'CharCode': 'HKD',
#   'Nominal': '10',
#   'Name': 'Гонконгских долларов',
#   'Value': '74,2414'},
#  {'@ID': 'R01215',
#   'NumCode': '208',
#   'CharCode': 'DKK',
#   'Nominal': '10',
#   'Name': 'Датских крон',
#   'Value': '75,4606'},
#  {'@ID': 'R01235',
#   'NumCode': '840',
#   'CharCode': 'USD',
#   'Nominal': '1',
#   'Name': 'Доллар США',
#   'Value': '58,1756'},
#  {'@ID': 'R01239',
#   'NumCode': '978',
#   'CharCode': 'EUR',
#   'Nominal': '1',
#   'Name': 'Евро',
#   'Value': '55,9953'},
#  {'@ID': 'R01270',
#   'NumCode': '356',
#   'CharCode': 'INR',
#   'Nominal': '100',
#   'Name': 'Индийских рупий',
#   'Value': '73,0136'},
#  {'@ID': 'R01335',
#   'NumCode': '398',
#   'CharCode': 'KZT',
#   'Nominal': '100',
#   'Name': 'Казахстанских тенге',
#   'Value': '12,1867'},
#  {'@ID': 'R01350',
#   'NumCode': '124',
#   'CharCode': 'CAD',
#   'Nominal': '1',
#   'Name': 'Канадский доллар',
#   'Value': '42,4144'},
#  {'@ID': 'R01370',
#   'NumCode': '417',
#   'CharCode': 'KGS',
#   'Nominal': '100',
#   'Name': 'Киргизских сомов',
#   'Value': '72,2618'},
#  {'@ID': 'R01375',
#   'NumCode': '156',
#   'CharCode': 'CNY',
#   'Nominal': '10',
#   'Name': 'Китайских юаней',
#   'Value': '81,0556'},
#  {'@ID': 'R01500',
#   'NumCode': '498',
#   'CharCode': 'MDL',
#   'Nominal': '10',
#   'Name': 'Молдавских леев',
#   'Value': '29,8563'},
#  {'@ID': 'R01535',
#   'NumCode': '578',
#   'CharCode': 'NOK',
#   'Nominal': '10',
#   'Name': 'Норвежских крон',
#   'Value': '54,1965'},
#  {'@ID': 'R01565',
#   'NumCode': '985',
#   'CharCode': 'PLN',
#   'Nominal': '1',
#   'Name': 'Польский злотый',
#   'Value': '11,7781'},
#  {'@ID': 'R01585F',
#   'NumCode': '946',
#   'CharCode': 'RON',
#   'Nominal': '1',
#   'Name': 'Румынский лей',
#   'Value': '11,3228'},
#  {'@ID': 'R01589',
#   'NumCode': '960',
#   'CharCode': 'XDR',
#   'Nominal': '1',
#   'Name': 'СДР (специальные права заимствования)',
#   'Value': '73,9988'},
#  {'@ID': 'R01625',
#   'NumCode': '702',
#   'CharCode': 'SGD',
#   'Nominal': '1',
#   'Name': 'Сингапурский доллар',
#   'Value': '40,5292'},
#  {'@ID': 'R01670',
#   'NumCode': '972',
#   'CharCode': 'TJS',
#   'Nominal': '10',
#   'Name': 'Таджикских сомони',
#   'Value': '56,8993'},
#  {'@ID': 'R01700J',
#   'NumCode': '949',
#   'CharCode': 'TRY',
#   'Nominal': '10',
#   'Name': 'Турецких лир',
#   'Value': '31,5431'},
#  {'@ID': 'R01710A',
#   'NumCode': '934',
#   'CharCode': 'TMT',
#   'Nominal': '1',
#   'Name': 'Новый туркменский манат',
#   'Value': '16,6216'},
#  {'@ID': 'R01717',
#   'NumCode': '860',
#   'CharCode': 'UZS',
#   'Nominal': '10000',
#   'Name': 'Узбекских сумов',
#   'Value': '52,6558'},
#  {'@ID': 'R01720',
#   'NumCode': '980',
#   'CharCode': 'UAH',
#   'Nominal': '10',
#   'Name': 'Украинских гривен',
#   'Value': '15,7579'},
#  {'@ID': 'R01760',
#   'NumCode': '203',
#   'CharCode': 'CZK',
#   'Nominal': '10',
#   'Name': 'Чешских крон',
#   'Value': '22,7836'},
#  {'@ID': 'R01770',
#   'NumCode': '752',
#   'CharCode': 'SEK',
#   'Nominal': '10',
#   'Name': 'Шведских крон',
#   'Value': '51,7604'},
#  {'@ID': 'R01775',
#   'NumCode': '756',
#   'CharCode': 'CHF',
#   'Nominal': '1',
#   'Name': 'Швейцарский франк',
#   'Value': '58,8703'},
#  {'@ID': 'R01810',
#   'NumCode': '710',
#   'CharCode': 'ZAR',
#   'Nominal': '10',
#   'Name': 'Южноафриканских рэндов',
#   'Value': '32,4019'},
#  {'@ID': 'R01815',
#   'NumCode': '410',
#   'CharCode': 'KRW',
#   'Nominal': '1000',
#   'Name': 'Вон Республики Корея',
#   'Value': '40,9255'},
#  {'@ID': 'R01820',
#   'NumCode': '392',
#   'CharCode': 'JPY',
#   'Nominal': '100',
#   'Name': 'Японских иен',
#   'Value': '40,2739'}]

# %%
my_array = []
for item in data ['ValCurs']['Valute']:
    my_set = [item['CharCode'], item['Name'], item['Value']];
    my_array.append(my_set)
    print(my_set)
# Out:
# ['AUD', 'Австралийский доллар', '37,8200']
# ['AZN', 'Азербайджанский манат', '34,2209']
# ['GBP', 'Фунт стерлингов Соединенного королевства', '62,7540']
# ['AMD', 'Армянских драмов', '14,1954']
# ['BYN', 'Белорусский рубль', '23,3674']
# ['BGN', 'Болгарский лев', '28,6919']
# ['BRL', 'Бразильский реал', '10,8648']
# ['HUF', 'Венгерских форинтов', '13,7411']
# ['HKD', 'Гонконгских долларов', '74,2414']
# ['DKK', 'Датских крон', '75,4606']
# ['USD', 'Доллар США', '58,1756']
# ['EUR', 'Евро', '55,9953']
# ['INR', 'Индийских рупий', '73,0136']
# ['KZT', 'Казахстанских тенге', '12,1867']
# ['CAD', 'Канадский доллар', '42,4144']
# ['KGS', 'Киргизских сомов', '72,2618']
# ['CNY', 'Китайских юаней', '81,0556']
# ['MDL', 'Молдавских леев', '29,8563']
# ['NOK', 'Норвежских крон', '54,1965']
# ['PLN', 'Польский злотый', '11,7781']
# ['RON', 'Румынский лей', '11,3228']
# ['XDR', 'СДР (специальные права заимствования)', '73,9988']
# ['SGD', 'Сингапурский доллар', '40,5292']
# ['TJS', 'Таджикских сомони', '56,8993']
# ['TRY', 'Турецких лир', '31,5431']
# ['TMT', 'Новый туркменский манат', '16,6216']
# ['UZS', 'Узбекских сумов', '52,6558']
# ['UAH', 'Украинских гривен', '15,7579']
# ['CZK', 'Чешских крон', '22,7836']
# ['SEK', 'Шведских крон', '51,7604']
# ['CHF', 'Швейцарский франк', '58,8703']
# ['ZAR', 'Южноафриканских рэндов', '32,4019']
# ['KRW', 'Вон Республики Корея', '40,9255']
# ['JPY', 'Японских иен', '40,2739']

# %%
my_array
# Out:
# [['AUD', 'Австралийский доллар', '37,8200'],
#  ['AZN', 'Азербайджанский манат', '34,2209'],
#  ['GBP', 'Фунт стерлингов Соединенного королевства', '62,7540'],
#  ['AMD', 'Армянских драмов', '14,1954'],
#  ['BYN', 'Белорусский рубль', '23,3674'],
#  ['BGN', 'Болгарский лев', '28,6919'],
#  ['BRL', 'Бразильский реал', '10,8648'],
#  ['HUF', 'Венгерских форинтов', '13,7411'],
#  ['HKD', 'Гонконгских долларов', '74,2414'],
#  ['DKK', 'Датских крон', '75,4606'],
#  ['USD', 'Доллар США', '58,1756'],
#  ['EUR', 'Евро', '55,9953'],
#  ['INR', 'Индийских рупий', '73,0136'],
#  ['KZT', 'Казахстанских тенге', '12,1867'],
#  ['CAD', 'Канадский доллар', '42,4144'],
#  ['KGS', 'Киргизских сомов', '72,2618'],
#  ['CNY', 'Китайских юаней', '81,0556'],
#  ['MDL', 'Молдавских леев', '29,8563'],
#  ['NOK', 'Норвежских крон', '54,1965'],
#  ['PLN', 'Польский злотый', '11,7781'],
#  ['RON', 'Румынский лей', '11,3228'],
#  ['XDR', 'СДР (специальные права заимствования)', '73,9988'],
#  ['SGD', 'Сингапурский доллар', '40,5292'],
#  ['TJS', 'Таджикских сомони', '56,8993'],
#  ['TRY', 'Турецких лир', '31,5431'],
#  ['TMT', 'Новый туркменский манат', '16,6216'],
#  ['UZS', 'Узбекских сумов', '52,6558'],
#  ['UAH', 'Украинских гривен', '15,7579'],
#  ['CZK', 'Чешских крон', '22,7836'],
#  ['SEK', 'Шведских крон', '51,7604'],
#  ['CHF', 'Швейцарский франк', '58,8703'],
#  ['ZAR', 'Южноафриканских рэндов', '32,4019'],
#  ['KRW', 'Вон Республики Корея', '40,9255'],
#  ['JPY', 'Японских иен', '40,2739']]
